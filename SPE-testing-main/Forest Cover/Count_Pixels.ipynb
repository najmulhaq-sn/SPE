# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# load image
img = cv2.imread('./Data/Test1/image.png')
plt.imshow(img)
plt.show()

# %%
# load image
img = cv2.imread(r'C:\Users\User\OneDrive - Engenuity (Pvt) Ltd\Github\SPE-testing\Sentinel-hub API\Data\response_g.png')
plt.imshow(img)
plt.show()

# %%
# convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(hsv)

# create mask for green color in hsv
# blue is 240 in range 0 to 360, so for opencv it would be 120
lower = (50,100,100)
upper = (70,255,255)
mask = cv2.inRange(hsv, lower, upper)

# %%
# count non-zero pixels in mask
count=np.count_nonzero(mask)
print('count:', count)
# Out:
# count: 58191

# %%
plt.imshow(mask)

# %%
# count pixels in mask
ct=np.shape(mask)
print('count:', ct)
# Out:
# count: (480, 640)

# %%
# counting the number of pixels
number_of_white_pix = np.sum(mask == 255)
number_of_black_pix = np.sum(mask == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
# Out:
# Number of white pixels: 58191
# Number of black pixels: 249009
