# %%
# !python --version
# Out:
# Python 3.8.0

# %% [markdown]
# # Package to install
# !pip install rasterio
# !pip install rioxarray
# !pip install geopandas
# !pip install earthpy

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import rasterio
import rioxarray as rxr
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
from matplotlib.colors import ListedColormap

# %% [markdown]
# ### Functions

# %%
# NDVI Calculation

def ndvi(red,nir):
    
    # read the both .tiff files for red(B04) & nir (B08)
    red_file = rxr.open_rasterio(img_path+'/'+red)
    nir_file = rxr.open_rasterio(img_path+'/'+nir)
    
    # calculate the NDVI
    ndvi = es.normalized_diff(nir_file[0], red_file[0])
    
    # plot the results
    ep.plot_bands(ndvi,
              cmap='PiYG',
              scale=False,
              vmin=-1, vmax=1,
              title="Sentinel2 L2C Derived NDVI")
    plt.show()
    
    return ndvi

# Vegetation classification

def veg_class(ndvi,save_path,file):
    
    # Create classes and apply to NDVI results
    ndvi_class_bins = [-np.inf, 0.6, np.inf]
    ndvi_landsat_class = np.digitize(ndvi, ndvi_class_bins)

    # Apply the nodata mask to the newly classified NDVI data
    ndvi_landsat_class = np.ma.masked_where(np.ma.getmask(ndvi), 
                                            ndvi_landsat_class)
    #np.unique(ndvi_landsat_class)
    
    # Define color map
    nbr_colors = ["gray", "g"]
    nbr_cmap = ListedColormap(nbr_colors)

    # Define class names
    ndvi_cat_names = [
        "No Vegetation",
        "Vegetation"]

    # Get list of classes
    classes = np.unique(ndvi_landsat_class)
    classes = classes.tolist()
    
    # The mask returns a value of none in the classes. remove that
    classes = classes[0:2]

    # Plot your data
    fig, ax = plt.subplots()
    im = ax.imshow(ndvi_landsat_class, cmap=nbr_cmap)
    ax.set_axis_off()
    canvas = plt.gca().figure.canvas
    canvas.draw()
    data = np.frombuffer(canvas.tostring_rgb(), dtype=np.uint8)
    image = data.reshape(canvas.get_width_height()[::-1] + (3,))
    
    #save img
    plt.savefig(save_path+'/'+os.path.splitext(file)[0]+'_g'+'.png')
    veg_file = os.path.splitext(file)[0]+'_g'+'.png'
    print(os.path.splitext(file)[0]+'_g'+'.png'+'\n'+"successfully saved!")

    return veg_file

# read img

def read_img(path,file):
    img = cv2.imread(path+'/'+file)
    plt.imshow(img)
    plt.show()
    
# count green pixels

def pixel_count(image):
    
    hsvImg = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    light_green = (50, 100, 100)
    dark_green = (70, 255, 255)

    mask = cv2.inRange(hsvImg, light_green, dark_green)

    number_of_white_pix = np.sum(mask == 255)
    number_of_black_pix = np.sum(mask == 0)

    #print('Number of white pixels:', number_of_white_pix)
    #print('Number of black pixels:', number_of_black_pix)
    
    return number_of_white_pix

# %% [markdown]
# ## Test1 - SL_Sinharaja

# %%
img_path = './Data/Test/SL_Sinharaja'
true_file = '2022-08-15-00_00_2022-08-15-23_59_Sentinel-2_L2A_True_color.tiff'
red_file = '2022-08-15-00_00_2022-08-15-23_59_Sentinel-2_L2A_B04_(Raw).tiff'
nir_file = '2022-08-15-00_00_2022-08-15-23_59_Sentinel-2_L2A_B08_(Raw).tiff'

# %%
# Show true color img

# %%
ndvi = ndvi(red_file,nir_file)

# %%
veg_file = veg_class(ndvi,img_path,true_file)
# Out:
# 2022-08-15-00_00_2022-08-15-23_59_Sentinel-2_L2A_True_color_g.png
# successfully saved!

# %% [markdown]
# ### Read Img

# %%
img = read_img(img_path,veg_file)
img

# %%
pixel_count(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 pixel_count(img)
#
# Cell In [58], line 78, in pixel_count(image)
#      76 def pixel_count(image):
# ---> 78     hsvImg = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#      80     light_green = (50, 100, 100)
#      81     dark_green = (70, 255, 255)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ### Count green pixels

# %%
# convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h,s,v = cv2.split(hsv)

# create mask for green color in hsv
lower = (50,100,100)
upper = (70,255,255)
mask = cv2.inRange(hsv, lower, upper)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [65], line 2
#       1 # convert to HSV
# ----> 2 hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#       3 h,s,v = cv2.split(hsv)
#       5 # create mask for green color in hsv
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
plt.imshow(mask)

# %%
# count non-zero pixels in mask
count=np.count_nonzero(mask)
print('count:', count)
# Out:
# count: 130972

# %%
# counting the number of pixels
number_of_white_pix = np.sum(mask == 255)
number_of_black_pix = np.sum(mask == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)
# Out:
# Number of white pixels: 130972
# Number of black pixels: 176228
